# %%
import warnings
warnings.filterwarnings("ignore", category=Warning)

import pickle
import structlog
from ml_assemblr.main_components.data_pod import DataPod
from home_credit_helper.config import cfg
from ml_assemblr.transfromer.model.xgb_model import XGBModel
from home_credit_helper.evaluation.main import evaluation

# %%
with open(cfg.research_cache_path / "05_feature_selection_states.pkl", "rb") as f:
    feature_selection_states: dict = pickle.load(f)

# %%
dp_untrain: DataPod = feature_selection_states["dp_untrain"]
feature_names = feature_selection_states["feature_names"]
current_feature_names = feature_selection_states["current_feature_names"]
low_important_feature_count = feature_selection_states["low_important_feature_count"]
metric_tolerance = feature_selection_states["metric_tolerance"]
total_original_features_count = feature_selection_states["total_original_features_count"]
xgb_config = feature_selection_states["xgb_config"]
auroc_full = feature_selection_states["auroc_full"]
count = feature_selection_states["count"] if "count" in feature_selection_states else 0

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
logger = structlog.get_logger()

# %%
while count < len(feature_names):
    
    feature_name_to_eval = feature_names[count]
    
    logging_context = (
        {"evaluating_feature": feature_name_to_eval}
        if feature_name_to_eval not in set(("first_loop", "last_loop"))
        else {}
    )

    logger.info(
        f"{count + 1} / {len(feature_names)} recursive feature elimination processing",
        **logging_context,
    )

    feature_names_to_train = current_feature_names[:]
    if feature_name_to_eval not in set(("first_loop", "last_loop")):
        feature_names_to_train.remove(feature_name_to_eval)

    dp = dp_untrain.copy()

    dp.main_column_type.features = feature_names_to_train
    
    cv_count = len(dp.variables["cv_idx_map"]['cv_split_idx_in_column_type'])
    for i in range(cv_count):
        xgb_model = XGBModel(**xgb_config, fit_on_split="train", cv_idx=i)
        dp: DataPod = dp.fit_transform(xgb_model)
        
    dp = evaluation(dp, "auroc_valid", fast_mode=True)
    auroc_iteration = dp.variables["evaluation"]["objective_auroc_valid"]

    auroc_diff = auroc_full - auroc_iteration

    metric_context = {
        "auroc_diff": auroc_diff,
        "auroc_iteration": auroc_iteration,
        "auroc_full": auroc_full,
        "remaining_features": len(current_feature_names)
    }

    if feature_name_to_eval == "first_loop":
        logger.info(
            f"remove all features with 0 importance ({low_important_feature_count} features)",
            **metric_context,
        )
    elif feature_name_to_eval == "last_loop":
        logger.info(
            f"final auroc after recursive feature elimination",
            **metric_context,
        )
    elif auroc_diff >= metric_tolerance:
        logger.info(
            f"keep feature: '{feature_name_to_eval}'",
            **metric_context,
        )
    else:
        metric_context["remaining_features"] -= 1
        logger.info(
            f"remove feature: '{feature_name_to_eval}'",
            **metric_context,
        )
        current_feature_names.remove(feature_name_to_eval)
        auroc_full = max(auroc_full, auroc_iteration)
        
    count += 1
    
    if count % 5 == 0 or count == len(feature_names):
    
        feature_selection_states = {
            "dp_untrain": dp_untrain,
            "feature_names": feature_names,
            "current_feature_names": current_feature_names,
            "low_important_feature_count": low_important_feature_count,
            "metric_tolerance": metric_tolerance,
            "total_original_features_count": total_original_features_count,
            "xgb_config": xgb_config,
            "auroc_full": auroc_full,
            "count": count
        }
        with open(cfg.research_cache_path / "05_feature_selection_states.pkl", "wb") as f:
            pickle.dump(feature_selection_states, f)
        logger.info(
            f"save feature_selection_states", **{"count":count, "recent_evaluated_features": feature_name_to_eval}
        )
    


logger.info("DONE!!")
logger.info(
    f"remaining {len(current_feature_names)} features from original {total_original_features_count} features"
)
# Out:
# 2024-04-21 16:19:29 [info     ] 51 / 448 recursive feature elimination processing evaluating_feature=LIVINGAPARTMENTS_AVG
# 2024-04-21 16:20:20 [info     ] keep feature: 'LIVINGAPARTMENTS_AVG' auroc_diff=0.000991475478971715 auroc_full=0.7729092416754991 auroc_iteration=0.7719177661965274 remaining_features=408
# 2024-04-21 16:20:20 [info     ] 52 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_NAME_SELLER_INDUSTRY_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 16:21:15 [info     ] keep feature: 'PREV_APPS_REFUSED_NAME_SELLER_INDUSTRY_INFREQUENT_SKLEARN_MEAN' auroc_diff=0.0007050271763884286 auroc_full=0.7729092416754991 auroc_iteration=0.7722042144991107 remaining_features=408
# 2024-04-21 16:21:15 [info     ] 53 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_PRODUCT_COMBINATION_CASH_X_SELL_LOW_MEAN
# 2024-04-21 16:22:11 [info     ] keep feature: 'PREV_APPS_APPROVED_PRODUCT_COMBINATION_CASH_X_SELL_LOW_MEAN' auroc_diff=0.001236639319149191 auroc_full=0.7729092416754991 auroc_iteration=0.7716726023563499 remaining_features=408
# 2024-04-21 16:22:11 [info     ] 54 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_AMT_CREDIT_MEAN
# 2024-04-21 16:23:08 [info     ] remove feature: 'PREV_APPS_APPROVED_AMT_CREDIT_MEAN' auroc_diff=0.0004802491090255545 auroc_full=0.7729092416754991 auroc_iteration=0.7724289925664736 remaining_features=407
# 2024-04-21 16:23:08 [info     ] 55 / 448 recursive feature elimination processing evaluating_feature=OCCUPATION_TYPE_INFREQUENT_SKLEARN
# 2024-04-21 16:24:04 [info     ] keep feature: 'OCCUPATION_TYPE_INFREQUENT_SKLEARN' auroc_diff=0.0006095784772256474 auroc_full=0.7729092416754991 auroc_iteration=0.7722996631982735 remaining_features=407
# 2024-04-21 16:24:08 [info     ] save feature_selection_states  count=55 recent_evaluated_features=OCCUPATION_TYPE_INFREQUENT_SKLEARN
# 2024-04-21 16:24:08 [info     ] 56 / 448 recursive feature elimination processing evaluating_feature=COMMONAREA_MODE
# 2024-04-21 16:25:03 [info     ] remove feature: 'COMMONAREA_MODE' auroc_diff=0.0004752287328649851 auroc_full=0.7729092416754991 auroc_iteration=0.7724340129426341 remaining_features=406
# 2024-04-21 16:25:03 [info     ] 57 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_ACTIVE_CREDIT_DAY_OVERDUE_MAX
# 2024-04-21 16:25:59 [info     ] remove feature: 'BUREAUS_ACTIVE_CREDIT_DAY_OVERDUE_MAX' auroc_diff=0.0004752287328649851 auroc_full=0.7729092416754991 auroc_iteration=0.7724340129426341 remaining_features=405
# 2024-04-21 16:25:59 [info     ] 58 / 448 recursive feature elimination processing evaluating_feature=POS_CASH_SK_DPD_MEAN
# 2024-04-21 16:26:54 [info     ] keep feature: 'POS_CASH_SK_DPD_MEAN' auroc_diff=0.0006100784529829983 auroc_full=0.7729092416754991 auroc_iteration=0.7722991632225161 remaining_features=405
# 2024-04-21 16:26:54 [info     ] 59 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_DRAWINGS_CURRENT_MAX
# 2024-04-21 16:27:50 [info     ] keep feature: 'CC_BALANCES_AMT_DRAWINGS_CURRENT_MAX' auroc_diff=0.0016909472234926115 auroc_full=0.7729092416754991 auroc_iteration=0.7712182944520065 remaining_features=405
# 2024-04-21 16:27:50 [info     ] 60 / 448 recursive feature elimination processing evaluating_feature=ELEVATORS_MODE
# 2024-04-21 16:28:45 [info     ] keep feature: 'ELEVATORS_MODE' auroc_diff=0.0009558734562397087 auroc_full=0.7729092416754991 auroc_iteration=0.7719533682192594 remaining_features=405
# 2024-04-21 16:28:48 [info     ] save feature_selection_states  count=60 recent_evaluated_features=ELEVATORS_MODE
# 2024-04-21 16:28:48 [info     ] 61 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_RATE_DOWN_PAYMENT_MAX
# 2024-04-21 16:29:43 [info     ] remove feature: 'PREV_APPS_REFUSED_RATE_DOWN_PAYMENT_MAX' auroc_diff=0.0004752287328649851 auroc_full=0.7729092416754991 auroc_iteration=0.7724340129426341 remaining_features=404
# 2024-04-21 16:29:43 [info     ] 62 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_AMT_APPLICATION_MIN
# 2024-04-21 16:30:37 [info     ] keep feature: 'PREV_APPS_AMT_APPLICATION_MIN' auroc_diff=0.0008023252675180004 auroc_full=0.7729092416754991 auroc_iteration=0.7721069164079811 remaining_features=404
# 2024-04-21 16:30:37 [info     ] 63 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_MONTHS_BALANCE_SUM
# 2024-04-21 16:31:32 [info     ] keep feature: 'CC_BALANCES_MONTHS_BALANCE_SUM' auroc_diff=0.0006103178300631562 auroc_full=0.7729092416754991 auroc_iteration=0.772298923845436 remaining_features=404
# 2024-04-21 16:31:32 [info     ] 64 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_NAME_CONTRACT_TYPE_CASH_LOANS_MEAN
# 2024-04-21 16:32:27 [info     ] keep feature: 'PREV_APPS_APPROVED_NAME_CONTRACT_TYPE_CASH_LOANS_MEAN' auroc_diff=0.0012131332620867186 auroc_full=0.7729092416754991 auroc_iteration=0.7716961084134124 remaining_features=404
# 2024-04-21 16:32:27 [info     ] 65 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_NAME_GOODS_CATEGORY_MOBILE_MEAN
# 2024-04-21 16:33:22 [info     ] keep feature: 'PREV_APPS_APPROVED_NAME_GOODS_CATEGORY_MOBILE_MEAN' auroc_diff=0.0012533292881379277 auroc_full=0.7729092416754991 auroc_iteration=0.7716559123873612 remaining_features=404
# 2024-04-21 16:33:26 [info     ] save feature_selection_states  count=65 recent_evaluated_features=PREV_APPS_APPROVED_NAME_GOODS_CATEGORY_MOBILE_MEAN
# 2024-04-21 16:33:26 [info     ] 66 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_DAYS_DECISION_MEAN
# 2024-04-21 16:34:20 [info     ] keep feature: 'PREV_APPS_REFUSED_DAYS_DECISION_MEAN' auroc_diff=0.0012690333208782434 auroc_full=0.7729092416754991 auroc_iteration=0.7716402083546209 remaining_features=404
# 2024-04-21 16:34:20 [info     ] 67 / 448 recursive feature elimination processing evaluating_feature=COMMONAREA_MEDI
# 2024-04-21 16:35:15 [info     ] remove feature: 'COMMONAREA_MEDI' auroc_diff=0.0004673465359426032 auroc_full=0.7729092416754991 auroc_iteration=0.7724418951395565 remaining_features=403
# 2024-04-21 16:35:15 [info     ] 68 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_NAME_PORTFOLIO_XNA_MEAN
# 2024-04-21 16:36:11 [info     ] remove feature: 'PREV_APPS_REFUSED_NAME_PORTFOLIO_XNA_MEAN' auroc_diff=0.0004673465359426032 auroc_full=0.7729092416754991 auroc_iteration=0.7724418951395565 remaining_features=402
# 2024-04-21 16:36:11 [info     ] 69 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN
# 2024-04-21 16:37:06 [info     ] keep feature: 'PREV_APPS_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN' auroc_diff=0.0008482646058034504 auroc_full=0.7729092416754991 auroc_iteration=0.7720609770696957 remaining_features=402
# 2024-04-21 16:37:06 [info     ] 70 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN
# 2024-04-21 16:38:01 [info     ] keep feature: 'PREV_APPS_REFUSED_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN' auroc_diff=0.0009258446181270585 auroc_full=0.7729092416754991 auroc_iteration=0.7719833970573721 remaining_features=402
# 2024-04-21 16:38:05 [info     ] save feature_selection_states  count=70 recent_evaluated_features=PREV_APPS_REFUSED_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN
# 2024-04-21 16:38:05 [info     ] 71 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CLOSED_STATUS_C_MEAN_MEAN
# 2024-04-21 16:38:59 [info     ] remove feature: 'BUREAUS_CLOSED_STATUS_C_MEAN_MEAN' auroc_diff=0.0004887919584485312 auroc_full=0.7729092416754991 auroc_iteration=0.7724204497170506 remaining_features=401
# 2024-04-21 16:38:59 [info     ] 72 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_RECEIVABLE_PRINCIPAL_VAR
# 2024-04-21 16:39:54 [info     ] keep feature: 'CC_BALANCES_AMT_RECEIVABLE_PRINCIPAL_VAR' auroc_diff=0.0010346265444167724 auroc_full=0.7729092416754991 auroc_iteration=0.7718746151310824 remaining_features=401
# 2024-04-21 16:39:54 [info     ] 73 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_CNT_DRAWINGS_ATM_CURRENT_MAX
# 2024-04-21 16:40:50 [info     ] keep feature: 'CC_BALANCES_CNT_DRAWINGS_ATM_CURRENT_MAX' auroc_diff=0.0007714394038563777 auroc_full=0.7729092416754991 auroc_iteration=0.7721378022716427 remaining_features=401
# 2024-04-21 16:40:50 [info     ] 74 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_NAME_CASH_LOAN_PURPOSE_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 16:41:44 [info     ] keep feature: 'PREV_APPS_NAME_CASH_LOAN_PURPOSE_INFREQUENT_SKLEARN_MEAN' auroc_diff=0.0015588565149244893 auroc_full=0.7729092416754991 auroc_iteration=0.7713503851605746 remaining_features=401
# 2024-04-21 16:41:44 [info     ] 75 / 448 recursive feature elimination processing evaluating_feature=AMT_REQ_CREDIT_BUREAU_DAY
# 2024-04-21 16:42:38 [info     ] keep feature: 'AMT_REQ_CREDIT_BUREAU_DAY' auroc_diff=0.0006547065836306487 auroc_full=0.7729092416754991 auroc_iteration=0.7722545350918685 remaining_features=401
# 2024-04-21 16:42:42 [info     ] save feature_selection_states  count=75 recent_evaluated_features=AMT_REQ_CREDIT_BUREAU_DAY
# 2024-04-21 16:42:42 [info     ] 76 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CLOSED_AMT_ANNUITY_MAX
# 2024-04-21 16:43:35 [info     ] keep feature: 'BUREAUS_CLOSED_AMT_ANNUITY_MAX' auroc_diff=0.0011386283799655894 auroc_full=0.7729092416754991 auroc_iteration=0.7717706132955335 remaining_features=401
# 2024-04-21 16:43:35 [info     ] 77 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_NAME_CONTRACT_STATUS_CANCELED_MEAN
# 2024-04-21 16:44:28 [info     ] remove feature: 'PREV_APPS_NAME_CONTRACT_STATUS_CANCELED_MEAN' auroc_diff=4.409678540473472e-05 auroc_full=0.7729092416754991 auroc_iteration=0.7728651448900944 remaining_features=400
# 2024-04-21 16:44:28 [info     ] 78 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_PAYMENT_CURRENT_MAX
# 2024-04-21 16:45:21 [info     ] remove feature: 'CC_BALANCES_AMT_PAYMENT_CURRENT_MAX' auroc_diff=0.00046611546317709696 auroc_full=0.7729092416754991 auroc_iteration=0.772443126212322 remaining_features=399
# 2024-04-21 16:45:21 [info     ] 79 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_ACTIVE_STATUS_INFREQUENT_SKLEARN_MEAN_MEAN
# 2024-04-21 16:46:13 [info     ] remove feature: 'BUREAUS_ACTIVE_STATUS_INFREQUENT_SKLEARN_MEAN_MEAN' auroc_diff=0.00046611546317709696 auroc_full=0.7729092416754991 auroc_iteration=0.772443126212322 remaining_features=398
# 2024-04-21 16:46:13 [info     ] 80 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_DRAWINGS_OTHER_CURRENT_MAX
# 2024-04-21 16:47:06 [info     ] remove feature: 'CC_BALANCES_AMT_DRAWINGS_OTHER_CURRENT_MAX' auroc_diff=0.0004776605036665993 auroc_full=0.7729092416754991 auroc_iteration=0.7724315811718325 remaining_features=397
# 2024-04-21 16:47:10 [info     ] save feature_selection_states  count=80 recent_evaluated_features=CC_BALANCES_AMT_DRAWINGS_OTHER_CURRENT_MAX
# 2024-04-21 16:47:10 [info     ] 81 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_PRODUCT_COMBINATION_POS_HOUSEHOLD_WITH_INTEREST_MEAN
# 2024-04-21 16:48:04 [info     ] keep feature: 'PREV_APPS_PRODUCT_COMBINATION_POS_HOUSEHOLD_WITH_INTEREST_MEAN' auroc_diff=0.0007431578626403423 auroc_full=0.7729092416754991 auroc_iteration=0.7721660838128588 remaining_features=397
# 2024-04-21 16:48:04 [info     ] 82 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_AMT_ANNUITY_MAX
# 2024-04-21 16:48:58 [info     ] remove feature: 'PREV_APPS_REFUSED_AMT_ANNUITY_MAX' auroc_diff=0.0004776605036665993 auroc_full=0.7729092416754991 auroc_iteration=0.7724315811718325 remaining_features=396
# 2024-04-21 16:48:58 [info     ] 83 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN
# 2024-04-21 16:49:52 [info     ] keep feature: 'PREV_APPS_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN' auroc_diff=0.001164636657646434 auroc_full=0.7729092416754991 auroc_iteration=0.7717446050178527 remaining_features=396
# 2024-04-21 16:49:52 [info     ] 84 / 448 recursive feature elimination processing evaluating_feature=BASEMENTAREA_MODE
# 2024-04-21 16:50:45 [info     ] keep feature: 'BASEMENTAREA_MODE' auroc_diff=0.0008449960616643271 auroc_full=0.7729092416754991 auroc_iteration=0.7720642456138348 remaining_features=396
# 2024-04-21 16:50:45 [info     ] 85 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CREDIT_ACTIVE_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 16:51:40 [info     ] keep feature: 'BUREAUS_CREDIT_ACTIVE_INFREQUENT_SKLEARN_MEAN' auroc_diff=0.0010217438498658638 auroc_full=0.7729092416754991 auroc_iteration=0.7718874978256333 remaining_features=396
# 2024-04-21 16:51:43 [info     ] save feature_selection_states  count=85 recent_evaluated_features=BUREAUS_CREDIT_ACTIVE_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 16:51:44 [info     ] 86 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_NAME_PRODUCT_TYPE_XNA_MEAN
# 2024-04-21 16:52:38 [info     ] keep feature: 'PREV_APPS_NAME_PRODUCT_TYPE_XNA_MEAN' auroc_diff=0.0010861138152883365 auroc_full=0.7729092416754991 auroc_iteration=0.7718231278602108 remaining_features=396
# 2024-04-21 16:52:38 [info     ] 87 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_CHANNEL_TYPE_REGIONAL_LOCAL_MEAN
# 2024-04-21 16:53:32 [info     ] remove feature: 'PREV_APPS_APPROVED_CHANNEL_TYPE_REGIONAL_LOCAL_MEAN' auroc_diff=0.0004096541993181546 auroc_full=0.7729092416754991 auroc_iteration=0.772499587476181 remaining_features=395
# 2024-04-21 16:53:32 [info     ] 88 / 448 recursive feature elimination processing evaluating_feature=LANDAREA_MODE
# 2024-04-21 16:54:25 [info     ] keep feature: 'LANDAREA_MODE'  auroc_diff=0.00086571726444995 auroc_full=0.7729092416754991 auroc_iteration=0.7720435244110492 remaining_features=395
# 2024-04-21 16:54:25 [info     ] 89 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_NAME_PORTFOLIO_XNA_MEAN
# 2024-04-21 16:55:20 [info     ] keep feature: 'PREV_APPS_NAME_PORTFOLIO_XNA_MEAN' auroc_diff=0.000557640294326256 auroc_full=0.7729092416754991 auroc_iteration=0.7723516013811729 remaining_features=395
# 2024-04-21 16:55:20 [info     ] 90 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_MONTHS_BALANCE_SIZE_MEAN
# 2024-04-21 16:56:16 [info     ] remove feature: 'BUREAUS_MONTHS_BALANCE_SIZE_MEAN' auroc_diff=0.0004096541993181546 auroc_full=0.7729092416754991 auroc_iteration=0.772499587476181 remaining_features=394
# 2024-04-21 16:56:19 [info     ] save feature_selection_states  count=90 recent_evaluated_features=BUREAUS_MONTHS_BALANCE_SIZE_MEAN
# 2024-04-21 16:56:19 [info     ] 91 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CLOSED_AMT_CREDIT_SUM_MAX
# 2024-04-21 16:57:14 [info     ] remove feature: 'BUREAUS_CLOSED_AMT_CREDIT_SUM_MAX' auroc_diff=0.0003288447943703421 auroc_full=0.7729092416754991 auroc_iteration=0.7725803968811288 remaining_features=393
# 2024-04-21 16:57:14 [info     ] 92 / 448 recursive feature elimination processing evaluating_feature=CNT_CHILDREN
# 2024-04-21 16:58:07 [info     ] remove feature: 'CNT_CHILDREN' auroc_diff=0.0003288447943703421 auroc_full=0.7729092416754991 auroc_iteration=0.7725803968811288 remaining_features=392
# 2024-04-21 16:58:07 [info     ] 93 / 448 recursive feature elimination processing evaluating_feature=FLOORSMAX_AVG
# 2024-04-21 16:58:59 [info     ] remove feature: 'FLOORSMAX_AVG' auroc_diff=0.0003288447943703421 auroc_full=0.7729092416754991 auroc_iteration=0.7725803968811288 remaining_features=391
# 2024-04-21 16:58:59 [info     ] 94 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN
# 2024-04-21 16:59:52 [info     ] remove feature: 'PREV_APPS_APPROVED_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN' auroc_diff=0.0002760944335579163 auroc_full=0.7729092416754991 auroc_iteration=0.7726331472419412 remaining_features=390
# 2024-04-21 16:59:52 [info     ] 95 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN
# 2024-04-21 17:00:44 [info     ] remove feature: 'BUREAUS_CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN' auroc_diff=4.787605806910733e-06 auroc_full=0.7729092416754991 auroc_iteration=0.7729044540696922 remaining_features=389
# 2024-04-21 17:00:47 [info     ] save feature_selection_states  count=95 recent_evaluated_features=BUREAUS_CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN
# 2024-04-21 17:00:47 [info     ] 96 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_NAME_SELLER_INDUSTRY_CONSUMER_ELECTRONICS_MEAN
# 2024-04-21 17:01:42 [info     ] remove feature: 'PREV_APPS_APPROVED_NAME_SELLER_INDUSTRY_CONSUMER_ELECTRONICS_MEAN' auroc_diff=0.0003555786070899014 auroc_full=0.7729092416754991 auroc_iteration=0.7725536630684092 remaining_features=388
# 2024-04-21 17:01:42 [info     ] 97 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_CHANNEL_TYPE_COUNTRY_WIDE_MEAN
# 2024-04-21 17:02:43 [info     ] remove feature: 'PREV_APPS_APPROVED_CHANNEL_TYPE_COUNTRY_WIDE_MEAN' auroc_diff=0.0003522312512462822 auroc_full=0.7729092416754991 auroc_iteration=0.7725570104242528 remaining_features=387
# 2024-04-21 17:02:43 [info     ] 98 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_PRODUCT_COMBINATION_POS_MOBILE_WITH_INTEREST_MEAN
# 2024-04-21 17:03:36 [info     ] remove feature: 'PREV_APPS_REFUSED_PRODUCT_COMBINATION_POS_MOBILE_WITH_INTEREST_MEAN' auroc_diff=0.0003522312512462822 auroc_full=0.7729092416754991 auroc_iteration=0.7725570104242528 remaining_features=386
# 2024-04-21 17:03:36 [info     ] 99 / 448 recursive feature elimination processing evaluating_feature=ANNUITY_INCOME_PERC
# 2024-04-21 17:04:27 [info     ] remove feature: 'ANNUITY_INCOME_PERC' auroc_diff=0.0004976858373448856 auroc_full=0.7729092416754991 auroc_iteration=0.7724115558381542 remaining_features=385
# 2024-04-21 17:04:27 [info     ] 100 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_MONTHS_BALANCE_MIN_MIN
# 2024-04-21 17:05:14 [info     ] keep feature: 'BUREAUS_MONTHS_BALANCE_MIN_MIN' auroc_diff=0.0011008442256161821 auroc_full=0.7729092416754991 auroc_iteration=0.7718083974498829 remaining_features=385
# 2024-04-21 17:05:18 [info     ] save feature_selection_states  count=100 recent_evaluated_features=BUREAUS_MONTHS_BALANCE_MIN_MIN
# 2024-04-21 17:05:18 [info     ] 101 / 448 recursive feature elimination processing evaluating_feature=APARTMENTS_MODE
# 2024-04-21 17:06:11 [info     ] keep feature: 'APARTMENTS_MODE' auroc_diff=0.0010950456468632463 auroc_full=0.7729092416754991 auroc_iteration=0.7718141960286359 remaining_features=385
# 2024-04-21 17:06:11 [info     ] 102 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_DRAWINGS_POS_CURRENT_SUM
# 2024-04-21 17:07:01 [info     ] remove feature: 'CC_BALANCES_AMT_DRAWINGS_POS_CURRENT_SUM' auroc_diff=3.5493109648010446e-06 auroc_full=0.7729092416754991 auroc_iteration=0.7729056923645343 remaining_features=384
# 2024-04-21 17:07:01 [info     ] 103 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_AMT_DOWN_PAYMENT_MEAN
# 2024-04-21 17:07:50 [info     ] remove feature: 'PREV_APPS_APPROVED_AMT_DOWN_PAYMENT_MEAN' auroc_diff=0.0002562323589572202 auroc_full=0.7729092416754991 auroc_iteration=0.7726530093165419 remaining_features=383
# 2024-04-21 17:07:50 [info     ] 104 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN
# 2024-04-21 17:08:41 [info     ] remove feature: 'BUREAUS_CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN' auroc_diff=7.268123728343401e-05 auroc_full=0.7729092416754991 auroc_iteration=0.7728365604382157 remaining_features=382
# 2024-04-21 17:08:41 [info     ] 105 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN
# 2024-04-21 17:09:33 [info     ] remove feature: 'PREV_APPS_REFUSED_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN' auroc_diff=7.268123728343401e-05 auroc_full=0.7729092416754991 auroc_iteration=0.7728365604382157 remaining_features=381
# 2024-04-21 17:09:37 [info     ] save feature_selection_states  count=105 recent_evaluated_features=PREV_APPS_REFUSED_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN
# 2024-04-21 17:09:37 [info     ] 106 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_ACTIVE_MONTHS_BALANCE_MIN_MIN
# 2024-04-21 17:10:27 [info     ] keep feature: 'BUREAUS_ACTIVE_MONTHS_BALANCE_MIN_MIN' auroc_diff=0.0006943338401372845 auroc_full=0.7729092416754991 auroc_iteration=0.7722149078353618 remaining_features=381
# 2024-04-21 17:10:27 [info     ] 107 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_NAME_TYPE_SUITE_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 17:11:19 [info     ] remove feature: 'PREV_APPS_APPROVED_NAME_TYPE_SUITE_INFREQUENT_SKLEARN_MEAN' auroc_diff=7.268123728343401e-05 auroc_full=0.7729092416754991 auroc_iteration=0.7728365604382157 remaining_features=380
# 2024-04-21 17:11:19 [info     ] 108 / 448 recursive feature elimination processing evaluating_feature=FLOORSMAX_MEDI
# 2024-04-21 17:12:11 [info     ] remove feature: 'FLOORSMAX_MEDI' auroc_diff=-0.00026660145446921746 auroc_full=0.7729092416754991 auroc_iteration=0.7731758431299683 remaining_features=379
# 2024-04-21 17:12:11 [info     ] 109 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_AMT_ANNUITY_MAX
# 2024-04-21 17:13:03 [info     ] remove feature: 'PREV_APPS_APPROVED_AMT_ANNUITY_MAX' auroc_diff=0.0 auroc_full=0.7731758431299683 auroc_iteration=0.7731758431299683 remaining_features=378
# 2024-04-21 17:13:03 [info     ] 110 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_PAYMENT_CURRENT_VAR
# 2024-04-21 17:13:54 [info     ] remove feature: 'CC_BALANCES_AMT_PAYMENT_CURRENT_VAR' auroc_diff=0.00012699467108845397 auroc_full=0.7731758431299683 auroc_iteration=0.7730488484588799 remaining_features=377
# 2024-04-21 17:13:58 [info     ] save feature_selection_states  count=110 recent_evaluated_features=CC_BALANCES_AMT_PAYMENT_CURRENT_VAR
# 2024-04-21 17:13:58 [info     ] 111 / 448 recursive feature elimination processing evaluating_feature=POS_CASH_SK_DPD_MAX
# 2024-04-21 17:14:49 [info     ] keep feature: 'POS_CASH_SK_DPD_MAX' auroc_diff=0.0005609072070337229 auroc_full=0.7731758431299683 auroc_iteration=0.7726149359229346 remaining_features=377
# 2024-04-21 17:14:49 [info     ] 112 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_MONTHS_BALANCE_SIZE
# 2024-04-21 17:15:39 [info     ] remove feature: 'CC_BALANCES_MONTHS_BALANCE_SIZE' auroc_diff=0.0003424756857863809 auroc_full=0.7731758431299683 auroc_iteration=0.772833367444182 remaining_features=376
# 2024-04-21 17:15:39 [info     ] 113 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_NAME_TYPE_SUITE_FAMILY_MEAN
# 2024-04-21 17:16:44 [info     ] keep feature: 'PREV_APPS_NAME_TYPE_SUITE_FAMILY_MEAN' auroc_diff=0.0005253204019362023 auroc_full=0.7731758431299683 auroc_iteration=0.7726505227280321 remaining_features=376
# 2024-04-21 17:16:44 [info     ] 114 / 448 recursive feature elimination processing evaluating_feature=YEARS_BEGINEXPLUATATION_AVG
# 2024-04-21 17:17:43 [info     ] keep feature: 'YEARS_BEGINEXPLUATATION_AVG' auroc_diff=0.0008488264151150782 auroc_full=0.7731758431299683 auroc_iteration=0.7723270167148533 remaining_features=376
# 2024-04-21 17:17:43 [info     ] 115 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CREDIT_TYPE_CREDIT_CARD_MEAN
# 2024-04-21 17:18:48 [info     ] keep feature: 'BUREAUS_CREDIT_TYPE_CREDIT_CARD_MEAN' auroc_diff=0.000883159139288936 auroc_full=0.7731758431299683 auroc_iteration=0.7722926839906794 remaining_features=376
# 2024-04-21 17:18:52 [info     ] save feature_selection_states  count=115 recent_evaluated_features=BUREAUS_CREDIT_TYPE_CREDIT_CARD_MEAN
# 2024-04-21 17:18:52 [info     ] 116 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_AMT_GOODS_PRICE_MEAN
# 2024-04-21 17:19:52 [info     ] keep feature: 'PREV_APPS_APPROVED_AMT_GOODS_PRICE_MEAN' auroc_diff=0.000908314970296531 auroc_full=0.7731758431299683 auroc_iteration=0.7722675281596718 remaining_features=376
# 2024-04-21 17:19:52 [info     ] 117 / 448 recursive feature elimination processing evaluating_feature=POS_CASH_NAME_CONTRACT_STATUS_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 17:20:55 [info     ] remove feature: 'POS_CASH_NAME_CONTRACT_STATUS_INFREQUENT_SKLEARN_MEAN' auroc_diff=0.0004931838416470935 auroc_full=0.7731758431299683 auroc_iteration=0.7726826592883212 remaining_features=375
# 2024-04-21 17:20:55 [info     ] 118 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_HOUR_APPR_PROCESS_START_MEAN
# 2024-04-21 17:21:54 [info     ] remove feature: 'PREV_APPS_REFUSED_HOUR_APPR_PROCESS_START_MEAN' auroc_diff=0.00045263065870004837 auroc_full=0.7731758431299683 auroc_iteration=0.7727232124712683 remaining_features=374
# 2024-04-21 17:21:54 [info     ] 119 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_BALANCE_SUM
# 2024-04-21 17:22:58 [info     ] keep feature: 'CC_BALANCES_AMT_BALANCE_SUM' auroc_diff=0.0005798685639182288 auroc_full=0.7731758431299683 auroc_iteration=0.7725959745660501 remaining_features=374
# 2024-04-21 17:22:58 [info     ] 120 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_NAME_YIELD_GROUP_XNA_MEAN
# 2024-04-21 17:24:01 [info     ] remove feature: 'PREV_APPS_REFUSED_NAME_YIELD_GROUP_XNA_MEAN' auroc_diff=0.00045263065870004837 auroc_full=0.7731758431299683 auroc_iteration=0.7727232124712683 remaining_features=373
# 2024-04-21 17:24:05 [info     ] save feature_selection_states  count=120 recent_evaluated_features=PREV_APPS_REFUSED_NAME_YIELD_GROUP_XNA_MEAN
# 2024-04-21 17:24:05 [info     ] 121 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_AMT_ANNUITY_MAX
# 2024-04-21 17:25:00 [info     ] remove feature: 'BUREAUS_AMT_ANNUITY_MAX' auroc_diff=0.00045263065870004837 auroc_full=0.7731758431299683 auroc_iteration=0.7727232124712683 remaining_features=372
# 2024-04-21 17:25:00 [info     ] 122 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CLOSED_AMT_ANNUITY_MEAN
# 2024-04-21 17:26:08 [info     ] keep feature: 'BUREAUS_CLOSED_AMT_ANNUITY_MEAN' auroc_diff=0.0016373434268481812 auroc_full=0.7731758431299683 auroc_iteration=0.7715384997031202 remaining_features=372
# 2024-04-21 17:26:08 [info     ] 123 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CLOSED_STATUS_INFREQUENT_SKLEARN_MEAN_MEAN
# 2024-04-21 17:27:07 [info     ] remove feature: 'BUREAUS_CLOSED_STATUS_INFREQUENT_SKLEARN_MEAN_MEAN' auroc_diff=0.00045263065870004837 auroc_full=0.7731758431299683 auroc_iteration=0.7727232124712683 remaining_features=371
# 2024-04-21 17:27:07 [info     ] 124 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_AMT_GOODS_PRICE_MEAN
# 2024-04-21 17:28:03 [info     ] keep feature: 'PREV_APPS_AMT_GOODS_PRICE_MEAN' auroc_diff=0.001068036212601875 auroc_full=0.7731758431299683 auroc_iteration=0.7721078069173665 remaining_features=371
# 2024-04-21 17:28:03 [info     ] 125 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_DRAWINGS_POS_CURRENT_VAR
# 2024-04-21 17:29:10 [info     ] remove feature: 'CC_BALANCES_AMT_DRAWINGS_POS_CURRENT_VAR' auroc_diff=0.00026346168638946565 auroc_full=0.7731758431299683 auroc_iteration=0.7729123814435789 remaining_features=370
# 2024-04-21 17:29:15 [info     ] save feature_selection_states  count=125 recent_evaluated_features=CC_BALANCES_AMT_DRAWINGS_POS_CURRENT_VAR
# 2024-04-21 17:29:15 [info     ] 126 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_HOUR_APPR_PROCESS_START_MIN
# 2024-04-21 17:30:19 [info     ] remove feature: 'PREV_APPS_APPROVED_HOUR_APPR_PROCESS_START_MIN' auroc_diff=0.0002635506257959719 auroc_full=0.7731758431299683 auroc_iteration=0.7729122925041724 remaining_features=369
# 2024-04-21 17:30:19 [info     ] 127 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_CNT_DRAWINGS_CURRENT_SUM
# 2024-04-21 17:31:21 [info     ] remove feature: 'CC_BALANCES_CNT_DRAWINGS_CURRENT_SUM' auroc_diff=0.0002635506257959719 auroc_full=0.7731758431299683 auroc_iteration=0.7729122925041724 remaining_features=368
# 2024-04-21 17:31:21 [info     ] 128 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN
# 2024-04-21 17:32:22 [info     ] remove feature: 'PREV_APPS_REFUSED_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN' auroc_diff=7.023510420245405e-05 auroc_full=0.7731758431299683 auroc_iteration=0.7731056080257659 remaining_features=367
# 2024-04-21 17:32:22 [info     ] 129 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_AMT_CREDIT_MEAN
# 2024-04-21 17:33:21 [info     ] remove feature: 'PREV_APPS_REFUSED_AMT_CREDIT_MEAN' auroc_diff=0.00046289999224247147 auroc_full=0.7731758431299683 auroc_iteration=0.7727129431377259 remaining_features=366
# 2024-04-21 17:33:21 [info     ] 130 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_NAME_GOODS_CATEGORY_CONSUMER_ELECTRONICS_MEAN
# 2024-04-21 17:34:13 [info     ] remove feature: 'PREV_APPS_NAME_GOODS_CATEGORY_CONSUMER_ELECTRONICS_MEAN' auroc_diff=0.00046289999224247147 auroc_full=0.7731758431299683 auroc_iteration=0.7727129431377259 remaining_features=365
# 2024-04-21 17:34:17 [info     ] save feature_selection_states  count=130 recent_evaluated_features=PREV_APPS_NAME_GOODS_CATEGORY_CONSUMER_ELECTRONICS_MEAN
# 2024-04-21 17:34:17 [info     ] 131 / 448 recursive feature elimination processing evaluating_feature=POS_CASH_NAME_CONTRACT_STATUS_COMPLETED_MEAN
# 2024-04-21 17:35:11 [info     ] keep feature: 'POS_CASH_NAME_CONTRACT_STATUS_COMPLETED_MEAN' auroc_diff=0.0009088852239075296 auroc_full=0.7731758431299683 auroc_iteration=0.7722669579060608 remaining_features=365
# 2024-04-21 17:35:11 [info     ] 132 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_PRODUCT_COMBINATION_CASH_X_SELL_MIDDLE_MEAN
# 2024-04-21 17:36:00 [info     ] keep feature: 'PREV_APPS_APPROVED_PRODUCT_COMBINATION_CASH_X_SELL_MIDDLE_MEAN' auroc_diff=0.0006875288703295235 auroc_full=0.7731758431299683 auroc_iteration=0.7724883142596388 remaining_features=365
# 2024-04-21 17:36:00 [info     ] 133 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_CHANNEL_TYPE_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 17:36:49 [info     ] remove feature: 'PREV_APPS_CHANNEL_TYPE_INFREQUENT_SKLEARN_MEAN' auroc_diff=0.00046289999224247147 auroc_full=0.7731758431299683 auroc_iteration=0.7727129431377259 remaining_features=364
# 2024-04-21 17:36:49 [info     ] 134 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_RECIVABLE_VAR
# 2024-04-21 17:37:37 [info     ] keep feature: 'CC_BALANCES_AMT_RECIVABLE_VAR' auroc_diff=0.0005201927649325366 auroc_full=0.7731758431299683 auroc_iteration=0.7726556503650358 remaining_features=364
# 2024-04-21 17:37:37 [info     ] 135 / 448 recursive feature elimination processing evaluating_feature=FLOORSMIN_AVG
# 2024-04-21 17:38:24 [info     ] remove feature: 'FLOORSMIN_AVG' auroc_diff=0.00045469342285786585 auroc_full=0.7731758431299683 auroc_iteration=0.7727211497071105 remaining_features=363
# 2024-04-21 17:38:27 [info     ] save feature_selection_states  count=135 recent_evaluated_features=FLOORSMIN_AVG
# 2024-04-21 17:38:27 [info     ] 136 / 448 recursive feature elimination processing evaluating_feature=YEARS_BUILD_AVG
# 2024-04-21 17:39:13 [info     ] keep feature: 'YEARS_BUILD_AVG' auroc_diff=0.001446298467092988 auroc_full=0.7731758431299683 auroc_iteration=0.7717295446628754 remaining_features=363
# 2024-04-21 17:39:13 [info     ] 137 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN
# 2024-04-21 17:40:01 [info     ] remove feature: 'PREV_APPS_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN' auroc_diff=0.0003706553474245311 auroc_full=0.7731758431299683 auroc_iteration=0.7728051877825438 remaining_features=362
# 2024-04-21 17:40:01 [info     ] 138 / 448 recursive feature elimination processing evaluating_feature=FLAG_OWN_REALTY
# 2024-04-21 17:40:51 [info     ] remove feature: 'FLAG_OWN_REALTY' auroc_diff=0.0003706553474245311 auroc_full=0.7731758431299683 auroc_iteration=0.7728051877825438 remaining_features=361
# 2024-04-21 17:40:51 [info     ] 139 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN
# 2024-04-21 17:41:38 [info     ] remove feature: 'PREV_APPS_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN' auroc_diff=0.0003706553474245311 auroc_full=0.7731758431299683 auroc_iteration=0.7728051877825438 remaining_features=360
# 2024-04-21 17:41:38 [info     ] 140 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CLOSED_MONTHS_BALANCE_SIZE_SUM
# 2024-04-21 17:42:27 [info     ] remove feature: 'BUREAUS_CLOSED_MONTHS_BALANCE_SIZE_SUM' auroc_diff=0.00033573004277376306 auroc_full=0.7731758431299683 auroc_iteration=0.7728401130871946 remaining_features=359
# 2024-04-21 17:42:31 [info     ] save feature_selection_states  count=140 recent_evaluated_features=BUREAUS_CLOSED_MONTHS_BALANCE_SIZE_SUM
# 2024-04-21 17:42:31 [info     ] 141 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_NAME_PAYMENT_TYPE_CASH_THROUGH_THE_BANK_MEAN
# 2024-04-21 17:43:20 [info     ] remove feature: 'PREV_APPS_APPROVED_NAME_PAYMENT_TYPE_CASH_THROUGH_THE_BANK_MEAN' auroc_diff=0.0003824495868254285 auroc_full=0.7731758431299683 auroc_iteration=0.7727933935431429 remaining_features=358
# 2024-04-21 17:43:20 [info     ] 142 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_AMT_GOODS_PRICE_MAX
# 2024-04-21 17:44:08 [info     ] keep feature: 'PREV_APPS_APPROVED_AMT_GOODS_PRICE_MAX' auroc_diff=0.001233539511956927 auroc_full=0.7731758431299683 auroc_iteration=0.7719423036180114 remaining_features=358
# 2024-04-21 17:44:08 [info     ] 143 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_AMT_ANNUITY_MIN
# 2024-04-21 17:44:57 [info     ] remove feature: 'PREV_APPS_APPROVED_AMT_ANNUITY_MIN' auroc_diff=0.00032858097530985564 auroc_full=0.7731758431299683 auroc_iteration=0.7728472621546585 remaining_features=357
# 2024-04-21 17:44:57 [info     ] 144 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_PAYMENT_TOTAL_CURRENT_MAX
# 2024-04-21 17:45:44 [info     ] keep feature: 'CC_BALANCES_AMT_PAYMENT_TOTAL_CURRENT_MAX' auroc_diff=0.0009154946054865665 auroc_full=0.7731758431299683 auroc_iteration=0.7722603485244818 remaining_features=357
# 2024-04-21 17:45:44 [info     ] 145 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_ACTIVE_MONTHS_BALANCE_MAX_MAX
# 2024-04-21 17:46:33 [info     ] keep feature: 'BUREAUS_ACTIVE_MONTHS_BALANCE_MAX_MAX' auroc_diff=0.001038709231515278 auroc_full=0.7731758431299683 auroc_iteration=0.7721371338984531 remaining_features=357
# 2024-04-21 17:46:37 [info     ] save feature_selection_states  count=145 recent_evaluated_features=BUREAUS_ACTIVE_MONTHS_BALANCE_MAX_MAX
# 2024-04-21 17:46:37 [info     ] 146 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_NAME_YIELD_GROUP_MIDDLE_MEAN
# 2024-04-21 17:47:25 [info     ] remove feature: 'PREV_APPS_APPROVED_NAME_YIELD_GROUP_MIDDLE_MEAN' auroc_diff=0.00022518889030787026 auroc_full=0.7731758431299683 auroc_iteration=0.7729506542396605 remaining_features=356
# 2024-04-21 17:47:25 [info     ] 147 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_DRAWINGS_POS_CURRENT_MEAN
# 2024-04-21 17:48:14 [info     ] remove feature: 'CC_BALANCES_AMT_DRAWINGS_POS_CURRENT_MEAN' auroc_diff=0.00022518889030787026 auroc_full=0.7731758431299683 auroc_iteration=0.7729506542396605 remaining_features=355
# 2024-04-21 17:48:14 [info     ] 148 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_ACTIVE_CREDIT_TYPE_CREDIT_CARD_MEAN
# 2024-04-21 17:49:00 [info     ] remove feature: 'BUREAUS_ACTIVE_CREDIT_TYPE_CREDIT_CARD_MEAN' auroc_diff=0.0002660059447731067 auroc_full=0.7731758431299683 auroc_iteration=0.7729098371851952 remaining_features=354
# 2024-04-21 17:49:00 [info     ] 149 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_HOUR_APPR_PROCESS_START_MEAN
# 2024-04-21 17:49:46 [info     ] keep feature: 'PREV_APPS_HOUR_APPR_PROCESS_START_MEAN' auroc_diff=0.0005553797670094784 auroc_full=0.7731758431299683 auroc_iteration=0.7726204633629589 remaining_features=354
# 2024-04-21 17:49:46 [info     ] 150 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_PRODUCT_COMBINATION_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 17:50:36 [info     ] remove feature: 'PREV_APPS_PRODUCT_COMBINATION_INFREQUENT_SKLEARN_MEAN' auroc_diff=0.0002660059447731067 auroc_full=0.7731758431299683 auroc_iteration=0.7729098371851952 remaining_features=353
# 2024-04-21 17:50:40 [info     ] save feature_selection_states  count=150 recent_evaluated_features=PREV_APPS_PRODUCT_COMBINATION_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 17:50:40 [info     ] 151 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_RECIVABLE_MAX
# 2024-04-21 17:51:26 [info     ] remove feature: 'CC_BALANCES_AMT_RECIVABLE_MAX' auroc_diff=0.0002660059447731067 auroc_full=0.7731758431299683 auroc_iteration=0.7729098371851952 remaining_features=352
# 2024-04-21 17:51:26 [info     ] 152 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_AMT_CREDIT_MAX
# 2024-04-21 17:52:14 [info     ] keep feature: 'PREV_APPS_APPROVED_AMT_CREDIT_MAX' auroc_diff=0.0009004003762784762 auroc_full=0.7731758431299683 auroc_iteration=0.7722754427536899 remaining_features=352
# 2024-04-21 17:52:14 [info     ] 153 / 448 recursive feature elimination processing evaluating_feature=COMMONAREA_AVG
# 2024-04-21 17:53:03 [info     ] keep feature: 'COMMONAREA_AVG' auroc_diff=0.0008884960023097799 auroc_full=0.7731758431299683 auroc_iteration=0.7722873471276586 remaining_features=352
# 2024-04-21 17:53:03 [info     ] 154 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_CREDIT_LIMIT_ACTUAL_MEAN
# 2024-04-21 17:53:51 [info     ] remove feature: 'CC_BALANCES_AMT_CREDIT_LIMIT_ACTUAL_MEAN' auroc_diff=0.0001203838739801677 auroc_full=0.7731758431299683 auroc_iteration=0.7730554592559882 remaining_features=351
# 2024-04-21 17:53:51 [info     ] 155 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_NAME_YIELD_GROUP_HIGH_MEAN
# 2024-04-21 17:54:37 [info     ] keep feature: 'PREV_APPS_REFUSED_NAME_YIELD_GROUP_HIGH_MEAN' auroc_diff=0.0005883845964325118 auroc_full=0.7731758431299683 auroc_iteration=0.7725874585335358 remaining_features=351
# 2024-04-21 17:54:41 [info     ] save feature_selection_states  count=155 recent_evaluated_features=PREV_APPS_REFUSED_NAME_YIELD_GROUP_HIGH_MEAN
# 2024-04-21 17:54:41 [info     ] 156 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_CODE_REJECT_REASON_HC_MEAN
# 2024-04-21 17:55:27 [info     ] remove feature: 'PREV_APPS_CODE_REJECT_REASON_HC_MEAN' auroc_diff=0.0001203838739801677 auroc_full=0.7731758431299683 auroc_iteration=0.7730554592559882 remaining_features=350
# 2024-04-21 17:55:27 [info     ] 157 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_CNT_INSTALMENT_MATURE_CUM_MEAN
# 2024-04-21 17:56:15 [info     ] remove feature: 'CC_BALANCES_CNT_INSTALMENT_MATURE_CUM_MEAN' auroc_diff=-7.457908448160744e-05 auroc_full=0.7731758431299683 auroc_iteration=0.77325042221445 remaining_features=349
# 2024-04-21 17:56:15 [info     ] 158 / 448 recursive feature elimination processing evaluating_feature=LIVINGAREA_MODE
# 2024-04-21 17:57:00 [info     ] remove feature: 'LIVINGAREA_MODE' auroc_diff=0.00014616310384929498 auroc_full=0.77325042221445 auroc_iteration=0.7731042591106007 remaining_features=348
# 2024-04-21 17:57:00 [info     ] 159 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CLOSED_MONTHS_BALANCE_SIZE_MEAN
# 2024-04-21 17:57:46 [info     ] keep feature: 'BUREAUS_CLOSED_MONTHS_BALANCE_SIZE_MEAN' auroc_diff=0.0007590733654735393 auroc_full=0.77325042221445 auroc_iteration=0.7724913488489764 remaining_features=348
# 2024-04-21 17:57:46 [info     ] 160 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_STATUS_C_MEAN_MEAN
# 2024-04-21 17:58:33 [info     ] keep feature: 'BUREAUS_STATUS_C_MEAN_MEAN' auroc_diff=0.0008438597034227113 auroc_full=0.77325042221445 auroc_iteration=0.7724065625110272 remaining_features=348
# 2024-04-21 17:58:37 [info     ] save feature_selection_states  count=160 recent_evaluated_features=BUREAUS_STATUS_C_MEAN_MEAN
# 2024-04-21 17:58:37 [info     ] 161 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_AMT_DOWN_PAYMENT_MEAN
# 2024-04-21 17:59:23 [info     ] remove feature: 'PREV_APPS_AMT_DOWN_PAYMENT_MEAN' auroc_diff=0.00021511689967090852 auroc_full=0.77325042221445 auroc_iteration=0.773035305314779 remaining_features=347
# 2024-04-21 17:59:23 [info     ] 162 / 448 recursive feature elimination processing evaluating_feature=OBS_30_CNT_SOCIAL_CIRCLE
# 2024-04-21 18:00:09 [info     ] keep feature: 'OBS_30_CNT_SOCIAL_CIRCLE' auroc_diff=0.0007239001958189162 auroc_full=0.77325042221445 auroc_iteration=0.772526522018631 remaining_features=347
# 2024-04-21 18:00:09 [info     ] 163 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_NAME_YIELD_GROUP_LOW_NORMAL_MEAN
# 2024-04-21 18:00:56 [info     ] keep feature: 'PREV_APPS_APPROVED_NAME_YIELD_GROUP_LOW_NORMAL_MEAN' auroc_diff=0.0006918032633008719 auroc_full=0.77325042221445 auroc_iteration=0.7725586189511491 remaining_features=347
# 2024-04-21 18:00:56 [info     ] 164 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_ACTIVE_AMT_ANNUITY_MAX
# 2024-04-21 18:01:40 [info     ] remove feature: 'BUREAUS_ACTIVE_AMT_ANNUITY_MAX' auroc_diff=0.00023675398113753854 auroc_full=0.77325042221445 auroc_iteration=0.7730136682333124 remaining_features=346
# 2024-04-21 18:01:40 [info     ] 165 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_AMT_GOODS_PRICE_MAX
# 2024-04-21 18:02:26 [info     ] remove feature: 'PREV_APPS_AMT_GOODS_PRICE_MAX' auroc_diff=0.00024921573667957553 auroc_full=0.77325042221445 auroc_iteration=0.7730012064777704 remaining_features=345
# 2024-04-21 18:02:30 [info     ] save feature_selection_states  count=165 recent_evaluated_features=PREV_APPS_AMT_GOODS_PRICE_MAX
# 2024-04-21 18:02:30 [info     ] 166 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CLOSED_CREDIT_TYPE_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 18:03:14 [info     ] remove feature: 'BUREAUS_CLOSED_CREDIT_TYPE_INFREQUENT_SKLEARN_MEAN' auroc_diff=0.00024921573667957553 auroc_full=0.77325042221445 auroc_iteration=0.7730012064777704 remaining_features=344
# 2024-04-21 18:03:14 [info     ] 167 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_CNT_DRAWINGS_CURRENT_MEAN
# 2024-04-21 18:04:01 [info     ] keep feature: 'CC_BALANCES_CNT_DRAWINGS_CURRENT_MEAN' auroc_diff=0.0007593597924023809 auroc_full=0.77325042221445 auroc_iteration=0.7724910624220476 remaining_features=344
# 2024-04-21 18:04:01 [info     ] 168 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_APP_CREDIT_PERC_MIN
# 2024-04-21 18:04:53 [info     ] remove feature: 'PREV_APPS_APPROVED_APP_CREDIT_PERC_MIN' auroc_diff=0.0002634103253721376 auroc_full=0.77325042221445 auroc_iteration=0.7729870118890778 remaining_features=343
# 2024-04-21 18:04:53 [info     ] 169 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_NAME_CLIENT_TYPE_NEW_MEAN
# 2024-04-21 18:05:39 [info     ] keep feature: 'PREV_APPS_REFUSED_NAME_CLIENT_TYPE_NEW_MEAN' auroc_diff=0.0009227532621975953 auroc_full=0.77325042221445 auroc_iteration=0.7723276689522524 remaining_features=343
# 2024-04-21 18:05:39 [info     ] 170 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_CNT_DRAWINGS_POS_CURRENT_SUM
# 2024-04-21 18:06:23 [info     ] remove feature: 'CC_BALANCES_CNT_DRAWINGS_POS_CURRENT_SUM' auroc_diff=0.00013105545273739416 auroc_full=0.77325042221445 auroc_iteration=0.7731193667617126 remaining_features=342
# 2024-04-21 18:06:27 [info     ] save feature_selection_states  count=170 recent_evaluated_features=CC_BALANCES_CNT_DRAWINGS_POS_CURRENT_SUM
# 2024-04-21 18:06:27 [info     ] 171 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_STATUS_X_MEAN_MEAN
# 2024-04-21 18:07:17 [info     ] keep feature: 'BUREAUS_STATUS_X_MEAN_MEAN' auroc_diff=0.000821837532293701 auroc_full=0.77325042221445 auroc_iteration=0.7724285846821562 remaining_features=342
# 2024-04-21 18:07:17 [info     ] 172 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_PRODUCT_COMBINATION_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 18:08:02 [info     ] remove feature: 'PREV_APPS_APPROVED_PRODUCT_COMBINATION_INFREQUENT_SKLEARN_MEAN' auroc_diff=0.00012157551887170825 auroc_full=0.77325042221445 auroc_iteration=0.7731288466955782 remaining_features=341
# 2024-04-21 18:08:02 [info     ] 173 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_NAME_YIELD_GROUP_MIDDLE_MEAN
# 2024-04-21 18:08:48 [info     ] remove feature: 'PREV_APPS_NAME_YIELD_GROUP_MIDDLE_MEAN' auroc_diff=0.0004997135165684119 auroc_full=0.77325042221445 auroc_iteration=0.7727507086978815 remaining_features=340
# 2024-04-21 18:08:48 [info     ] 174 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APP_CREDIT_PERC_VAR
# 2024-04-21 18:09:39 [info     ] remove feature: 'PREV_APPS_APP_CREDIT_PERC_VAR' auroc_diff=0.00031396438242969893 auroc_full=0.77325042221445 auroc_iteration=0.7729364578320203 remaining_features=339
# 2024-04-21 18:09:39 [info     ] 175 / 448 recursive feature elimination processing evaluating_feature=POS_CASH_SK_DPD_DEF_MAX
# 2024-04-21 18:10:26 [info     ] keep feature: 'POS_CASH_SK_DPD_DEF_MAX' auroc_diff=0.0013269069204944195 auroc_full=0.77325042221445 auroc_iteration=0.7719235152939555 remaining_features=339
# 2024-04-21 18:10:29 [info     ] save feature_selection_states  count=175 recent_evaluated_features=POS_CASH_SK_DPD_DEF_MAX
# 2024-04-21 18:10:29 [info     ] 176 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CLOSED_AMT_CREDIT_SUM_DEBT_MEAN
# 2024-04-21 18:11:15 [info     ] remove feature: 'BUREAUS_CLOSED_AMT_CREDIT_SUM_DEBT_MEAN' auroc_diff=-0.00019832128256047632 auroc_full=0.77325042221445 auroc_iteration=0.7734487434970104 remaining_features=338
# 2024-04-21 18:11:15 [info     ] 177 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_NAME_TYPE_SUITE_FAMILY_MEAN
# 2024-04-21 18:12:01 [info     ] remove feature: 'PREV_APPS_APPROVED_NAME_TYPE_SUITE_FAMILY_MEAN' auroc_diff=0.00032250310830372886 auroc_full=0.7734487434970104 auroc_iteration=0.7731262403887067 remaining_features=337
# 2024-04-21 18:12:01 [info     ] 178 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_NAME_SELLER_INDUSTRY_CONNECTIVITY_MEAN
# ...
# 2024-04-21 19:18:25 [info     ] 268 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_CHANNEL_TYPE_CREDIT_AND_CASH_OFFICES_MEAN
# 2024-04-21 19:19:15 [info     ] remove feature: 'PREV_APPS_APPROVED_CHANNEL_TYPE_CREDIT_AND_CASH_OFFICES_MEAN' auroc_diff=0.0004918093145148683 auroc_full=0.7738403548553405 auroc_iteration=0.7733485455408257 remaining_features=306
# 2024-04-21 19:19:15 [info     ] 269 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN
# 2024-04-21 19:20:06 [info     ] keep feature: 'BUREAUS_ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN' auroc_diff=0.0008095109210944917 auroc_full=0.7738403548553405 auroc_iteration=0.773030843934246 remaining_features=306
# 2024-04-21 19:20:06 [info     ] 270 / 448 recursive feature elimination processing evaluating_feature=FLAG_DOCUMENT_16
# 2024-04-21 19:21:01 [info     ] keep feature: 'FLAG_DOCUMENT_16' auroc_diff=0.0017226788551232275 auroc_full=0.7738403548553405 auroc_iteration=0.7721176760002173 remaining_features=306
# 2024-04-21 19:21:06 [info     ] save feature_selection_states  count=270 recent_evaluated_features=FLAG_DOCUMENT_16
# 2024-04-21 19:21:06 [info     ] 271 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_DAYS_CREDIT_ENDDATE_MIN
# 2024-04-21 19:22:15 [info     ] keep feature: 'BUREAUS_DAYS_CREDIT_ENDDATE_MIN' auroc_diff=0.000651874335351299 auroc_full=0.7738403548553405 auroc_iteration=0.7731884805199892 remaining_features=306
# 2024-04-21 19:22:15 [info     ] 272 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_ACTIVE_CREDIT_TYPE_CONSUMER_CREDIT_MEAN
# 2024-04-21 19:23:09 [info     ] keep feature: 'BUREAUS_ACTIVE_CREDIT_TYPE_CONSUMER_CREDIT_MEAN' auroc_diff=0.0005771249914502397 auroc_full=0.7738403548553405 auroc_iteration=0.7732632298638903 remaining_features=306
# 2024-04-21 19:23:09 [info     ] 273 / 448 recursive feature elimination processing evaluating_feature=INT_PAY_DBD_MEAN
# 2024-04-21 19:24:24 [info     ] keep feature: 'INT_PAY_DBD_MEAN' auroc_diff=0.0021668122666964607 auroc_full=0.7738403548553405 auroc_iteration=0.7716735425886441 remaining_features=306
# 2024-04-21 19:24:24 [info     ] 274 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_RECEIVABLE_PRINCIPAL_MIN
# 2024-04-21 19:25:15 [info     ] keep feature: 'CC_BALANCES_AMT_RECEIVABLE_PRINCIPAL_MIN' auroc_diff=0.0011275243096404708 auroc_full=0.7738403548553405 auroc_iteration=0.7727128305457001 remaining_features=306
# 2024-04-21 19:25:15 [info     ] 275 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_NAME_SELLER_INDUSTRY_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 19:26:08 [info     ] keep feature: 'PREV_APPS_APPROVED_NAME_SELLER_INDUSTRY_INFREQUENT_SKLEARN_MEAN' auroc_diff=0.0010509262983339207 auroc_full=0.7738403548553405 auroc_iteration=0.7727894285570066 remaining_features=306
# 2024-04-21 19:26:12 [info     ] save feature_selection_states  count=275 recent_evaluated_features=PREV_APPS_APPROVED_NAME_SELLER_INDUSTRY_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 19:26:12 [info     ] 276 / 448 recursive feature elimination processing evaluating_feature=AMT_INCOME_TOTAL
# 2024-04-21 19:27:07 [info     ] keep feature: 'AMT_INCOME_TOTAL' auroc_diff=0.00133752332313275 auroc_full=0.7738403548553405 auroc_iteration=0.7725028315322078 remaining_features=306
# 2024-04-21 19:27:07 [info     ] 277 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_DAYS_CREDIT_ENDDATE_MEAN
# 2024-04-21 19:28:01 [info     ] keep feature: 'BUREAUS_DAYS_CREDIT_ENDDATE_MEAN' auroc_diff=0.002603346391803263 auroc_full=0.7738403548553405 auroc_iteration=0.7712370084635373 remaining_features=306
# 2024-04-21 19:28:01 [info     ] 278 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_NAME_CONTRACT_TYPE_CASH_LOANS_MEAN
# 2024-04-21 19:29:00 [info     ] keep feature: 'PREV_APPS_REFUSED_NAME_CONTRACT_TYPE_CASH_LOANS_MEAN' auroc_diff=0.0005178443044093761 auroc_full=0.7738403548553405 auroc_iteration=0.7733225105509312 remaining_features=306
# 2024-04-21 19:29:00 [info     ] 279 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_DRAWINGS_ATM_CURRENT_VAR
# 2024-04-21 19:29:47 [info     ] keep feature: 'CC_BALANCES_AMT_DRAWINGS_ATM_CURRENT_VAR' auroc_diff=0.001177582173240932 auroc_full=0.7738403548553405 auroc_iteration=0.7726627726820996 remaining_features=306
# 2024-04-21 19:29:47 [info     ] 280 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_CREDIT_TYPE_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 19:30:48 [info     ] keep feature: 'BUREAUS_CREDIT_TYPE_INFREQUENT_SKLEARN_MEAN' auroc_diff=0.002287515552825359 auroc_full=0.7738403548553405 auroc_iteration=0.7715528393025152 remaining_features=306
# 2024-04-21 19:30:53 [info     ] save feature_selection_states  count=280 recent_evaluated_features=BUREAUS_CREDIT_TYPE_INFREQUENT_SKLEARN_MEAN
# 2024-04-21 19:30:53 [info     ] 281 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_PAYMENT_CURRENT_MEAN
# 2024-04-21 19:31:42 [info     ] keep feature: 'CC_BALANCES_AMT_PAYMENT_CURRENT_MEAN' auroc_diff=0.0022587107596301337 auroc_full=0.7738403548553405 auroc_iteration=0.7715816440957104 remaining_features=306
# 2024-04-21 19:31:42 [info     ] 282 / 448 recursive feature elimination processing evaluating_feature=CC_BALANCES_AMT_DRAWINGS_CURRENT_MEAN
# 2024-04-21 19:32:32 [info     ] keep feature: 'CC_BALANCES_AMT_DRAWINGS_CURRENT_MEAN' auroc_diff=0.0006156364894889244 auroc_full=0.7738403548553405 auroc_iteration=0.7732247183658516 remaining_features=306
# 2024-04-21 19:32:32 [info     ] 283 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_NAME_CASH_LOAN_PURPOSE_XNA_MEAN
# 2024-04-21 19:33:29 [info     ] remove feature: 'PREV_APPS_REFUSED_NAME_CASH_LOAN_PURPOSE_XNA_MEAN' auroc_diff=0.0004918093145148683 auroc_full=0.7738403548553405 auroc_iteration=0.7733485455408257 remaining_features=305
# 2024-04-21 19:33:29 [info     ] 284 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_DAYS_CREDIT_UPDATE_MEAN
# 2024-04-21 19:34:21 [info     ] remove feature: 'BUREAUS_DAYS_CREDIT_UPDATE_MEAN' auroc_diff=0.0004259016324003051 auroc_full=0.7738403548553405 auroc_iteration=0.7734144532229402 remaining_features=304
# 2024-04-21 19:34:21 [info     ] 285 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_DAYS_DECISION_MAX
# 2024-04-21 19:35:15 [info     ] keep feature: 'PREV_APPS_REFUSED_DAYS_DECISION_MAX' auroc_diff=0.001639544915590041 auroc_full=0.7738403548553405 auroc_iteration=0.7722008099397505 remaining_features=304
# 2024-04-21 19:35:20 [info     ] save feature_selection_states  count=285 recent_evaluated_features=PREV_APPS_REFUSED_DAYS_DECISION_MAX
# 2024-04-21 19:35:20 [info     ] 286 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_REFUSED_APP_CREDIT_PERC_VAR
# 2024-04-21 19:36:14 [info     ] remove feature: 'PREV_APPS_REFUSED_APP_CREDIT_PERC_VAR' auroc_diff=0.0003799072251252644 auroc_full=0.7738403548553405 auroc_iteration=0.7734604476302153 remaining_features=303
# 2024-04-21 19:36:14 [info     ] 287 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_NAME_CASH_LOAN_PURPOSE_XNA_MEAN
# 2024-04-21 19:37:06 [info     ] remove feature: 'PREV_APPS_APPROVED_NAME_CASH_LOAN_PURPOSE_XNA_MEAN' auroc_diff=0.0003799072251252644 auroc_full=0.7738403548553405 auroc_iteration=0.7734604476302153 remaining_features=302
# 2024-04-21 19:37:06 [info     ] 288 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_ACTIVE_MONTHS_BALANCE_SIZE_MEAN
# 2024-04-21 19:37:54 [info     ] remove feature: 'BUREAUS_ACTIVE_MONTHS_BALANCE_SIZE_MEAN' auroc_diff=0.00045028094630750193 auroc_full=0.7738403548553405 auroc_iteration=0.773390073909033 remaining_features=301
# 2024-04-21 19:37:54 [info     ] 289 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_RATE_DOWN_PAYMENT_MEAN
# 2024-04-21 19:38:43 [info     ] keep feature: 'PREV_APPS_APPROVED_RATE_DOWN_PAYMENT_MEAN' auroc_diff=0.0013226853455798881 auroc_full=0.7738403548553405 auroc_iteration=0.7725176695097606 remaining_features=301
# 2024-04-21 19:38:43 [info     ] 290 / 448 recursive feature elimination processing evaluating_feature=ENTRANCES_MEDI
# 2024-04-21 19:39:29 [info     ] keep feature: 'ENTRANCES_MEDI' auroc_diff=0.0010124357884500057 auroc_full=0.7738403548553405 auroc_iteration=0.7728279190668905 remaining_features=301
# 2024-04-21 19:39:33 [info     ] save feature_selection_states  count=290 recent_evaluated_features=ENTRANCES_MEDI
# 2024-04-21 19:39:33 [info     ] 291 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_ACTIVE_DAYS_CREDIT_MIN
# 2024-04-21 19:40:32 [info     ] keep feature: 'BUREAUS_ACTIVE_DAYS_CREDIT_MIN' auroc_diff=0.0010152495425092 auroc_full=0.7738403548553405 auroc_iteration=0.7728251053128313 remaining_features=301
# 2024-04-21 19:40:32 [info     ] 292 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_NAME_TYPE_SUITE_UNACCOMPANIED_MEAN
# 2024-04-21 19:41:27 [info     ] keep feature: 'PREV_APPS_APPROVED_NAME_TYPE_SUITE_UNACCOMPANIED_MEAN' auroc_diff=0.0012525386705254382 auroc_full=0.7738403548553405 auroc_iteration=0.7725878161848151 remaining_features=301
# 2024-04-21 19:41:27 [info     ] 293 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM
# 2024-04-21 19:42:23 [info     ] keep feature: 'BUREAUS_ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM' auroc_diff=0.0009366225456423072 auroc_full=0.7738403548553405 auroc_iteration=0.7729037323096982 remaining_features=301
# 2024-04-21 19:42:23 [info     ] 294 / 448 recursive feature elimination processing evaluating_feature=PREV_APPS_APPROVED_PRODUCT_COMBINATION_POS_INDUSTRY_WITH_INTEREST_MEAN
# 2024-04-21 19:43:21 [info     ] remove feature: 'PREV_APPS_APPROVED_PRODUCT_COMBINATION_POS_INDUSTRY_WITH_INTEREST_MEAN' auroc_diff=0.00045028094630750193 auroc_full=0.7738403548553405 auroc_iteration=0.773390073909033 remaining_features=300
# 2024-04-21 19:43:21 [info     ] 295 / 448 recursive feature elimination processing evaluating_feature=BUREAUS_DAYS_CREDIT_MIN
# 2024-04-21 19:44:14 [info     ] keep feature: 'BUREAUS_DAYS_CREDIT_MIN' auroc_diff=0.0010330960422869628 auroc_full=0.7738403548553405 auroc_iteration=0.7728072588130536 remaining_features=300
# 2024-04-21 19:44:18 [info     ] save feature_selection_states  count=295 recent_evaluated_features=BUREAUS_DAYS_CREDIT_MIN
# 2024-04-21 19:44:18 [info     ] 296 / 448 recursive feature elimination processing evaluating_feature=INT_PAY_PAYMENT_PERC_MAX
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 27
#      25 for i in range(cv_count):
#      26     xgb_model = XGBModel(**xgb_config, fit_on_split="train", cv_idx=i)
# ---> 27     dp: DataPod = dp.fit_transform(xgb_model)
#      29 dp = evaluation(dp, "auroc_valid", fast_mode=True)
#      30 auroc_iteration = dp.variables["evaluation"]["objective_auroc_valid"]
#
# File D:\05-repo\ml-assemblr\ml_assemblr\main_components\data_pod.py:51, in DataPod.fit_transform(self, transformer)
#      48 transformer = deepcopy(transformer)
#      50 # return transformer.fit_transform(self)
# ---> 51 dp_test = transformer.fit_transform(self)
#      52 return dp_test
#
# File D:\05-repo\ml-assemblr\ml_assemblr\main_components\base_class.py:45, in Transformer.fit_transform(self, data_pod)
#      41 def fit_transform(
#      42     self, data_pod: Union[BaseDataPod, "DataPod"]
#      43 ) -> Union[BaseDataPod, "DataPod", "DataPodList"]:
#      44     data_pod = self._call_hook_pre_fit_transform(data_pod)
# ---> 45     data_pod = self._fit_transform(data_pod)
#      46     data_pod = self._call_hook(data_pod)
#      48     return data_pod
#
# File D:\05-repo\ml-assemblr\ml_assemblr\transfromer\model\xgb_model.py:52, in XGBModel._fit_transform(self, data_pod)
#      43 dtrain = xgb.DMatrix(df_train_features, label=df_train_label)
#      45 self.model = xgb.train(
#      46     params=self.xgb_params,
#      47     dtrain=dtrain,
#      48     num_boost_round=self.num_boost_round,
#      49     verbose_eval=False,
#      50 )
# ---> 52 return self._transform(data_pod)
#
# File D:\05-repo\ml-assemblr\ml_assemblr\transfromer\model\xgb_model.py:58, in XGBModel._transform(self, data_pod)
#      54 def _transform(self, data_pod: DataPod) -> DataPod:
#      55     df_all_features = data_pod.slice_df(
#      56         split=None, columns="features", table_name=self.target_df_name
#      57     )
# ---> 58     dall = xgb.DMatrix(data=df_all_features)
#      60     data_pod.dfs[self.target_df_name][self.pred_col_name] = self.model.predict(dall)
#      62     return data_pod
#
# File c:\Users\Titta\.conda\envs\kaggle-home-credit-default-risk\Lib\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File c:\Users\Titta\.conda\envs\kaggle-home-credit-default-risk\Lib\site-packages\xgboost\core.py:857, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#     854     assert self.handle is not None
#     855     return
# --> 857 handle, feature_names, feature_types = dispatch_data_backend(
#     858     data,
#     859     missing=self.missing,
#     860     threads=self.nthread,
#     861     feature_names=feature_names,
#     862     feature_types=feature_types,
#     863     enable_categorical=enable_categorical,
#     864     data_split_mode=data_split_mode,
#     865 )
#     866 assert handle is not None
#     867 self.handle = handle
#
# File c:\Users\Titta\.conda\envs\kaggle-home-credit-default-risk\Lib\site-packages\xgboost\data.py:1089, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical, data_split_mode)
#    1087     data = pd.DataFrame(data)
#    1088 if _is_pandas_df(data):
# -> 1089     return _from_pandas_df(
#    1090         data, enable_categorical, missing, threads, feature_names, feature_types
#    1091     )
#    1092 if _is_cudf_df(data) or _is_cudf_ser(data):
#    1093     return _from_cudf_df(
#    1094         data, missing, threads, feature_names, feature_types, enable_categorical
#    1095     )
#
# File c:\Users\Titta\.conda\envs\kaggle-home-credit-default-risk\Lib\site-packages\xgboost\data.py:525, in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types)
#     514 def _from_pandas_df(
#     515     data: DataFrame,
#     516     enable_categorical: bool,
#    (...)
#     520     feature_types: Optional[FeatureTypes],
#     521 ) -> DispatchedDataBackendReturnType:
#     522     data, feature_names, feature_types = _transform_pandas_df(
#     523         data, enable_categorical, feature_names, feature_types
#     524     )
# --> 525     return _from_numpy_array(data, missing, nthread, feature_names, feature_types)
#
# File c:\Users\Titta\.conda\envs\kaggle-home-credit-default-risk\Lib\site-packages\xgboost\data.py:208, in _from_numpy_array(data, missing, nthread, feature_names, feature_types, data_split_mode)
#     205 data, _ = _ensure_np_dtype(data, data.dtype)
#     206 handle = ctypes.c_void_p()
#     207 _check_call(
# --> 208     _LIB.XGDMatrixCreateFromDense(
#     209         _array_interface(data),
#     210         make_jcargs(
#     211             missing=float(missing),
#     212             nthread=int(nthread),
#     213             data_split_mode=int(data_split_mode),
#     214         ),
#     215         ctypes.byref(handle),
#     216     )
#     217 )
#     218 return handle, feature_names, feature_types
#
# KeyboardInterrupt:

# %%
remaining_feature_names = current_feature_names 
print(len(remaining_feature_names))
remaining_feature_names[-10:]
# Out:
# 300
# ['OWN_CAR_AGE',
#  'NAME_EDUCATION_TYPE_HIGHER_EDUCATION',
#  'PAYMENT_RATE',
#  'CODE_GENDER_M',
#  'INT_PAY_DPD_MEAN',
#  'DAYS_EMPLOYED_PERC',
#  'AMT_GOODS_PRICE',
#  'EXT_SOURCE_1',
#  'EXT_SOURCE_3',
#  'EXT_SOURCE_2']

# %%
with open(cfg.research_cache_path / "06_selected_features.pkl", "wb") as f:
    pickle.dump(remaining_feature_names, f)
